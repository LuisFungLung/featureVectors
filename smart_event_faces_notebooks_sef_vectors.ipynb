# %%
import pickle

# %%
with open('../pickles/sef(smart_faces)_rn34_test_data_mask.pickle','rb') as f:
    x0 = pickle.load(f)
print(type(x0))
print(x0.keys())

with open('../pickles/sef(event_faces)_rn34_test_data_mask.pickle','rb') as f:
    x1 = pickle.load(f)
print(type(x1))
print(x1.keys())
# Out:
# <class 'dict'>
# dict_keys(['encodings', 'names'])
# <class 'dict'>
# dict_keys(['encodings', 'names'])

# %%
for i, e in enumerate(x0['names']):
    if(i%50==0):
        print(x0['names'][i], x0['encodings'][i])
# Out:
# 001 [ 0.02520478  0.11245678 -0.03989434 -0.04795954 -0.08842016  0.03568184
#  -0.1036087   0.00555765  0.14272428 -0.02595908  0.16856907 -0.0416792
#  -0.21296109  0.07985153 -0.01024604  0.09887259 -0.10835357 -0.10537359
#  -0.22374509 -0.09542171 -0.01458434  0.08285581  0.00387153  0.08893598
#  -0.17700675 -0.21293661 -0.03517793 -0.1262864   0.0791719  -0.15417764
#  -0.03303797 -0.07267474 -0.16437316 -0.02713674  0.04302381  0.03330643
#  -0.0410132  -0.16303556  0.26873684  0.0386987  -0.16493928  0.0314934
#   0.0660907   0.25143796  0.1673613  -0.01487572  0.03117052 -0.01068605
#   0.1373152  -0.26262057  0.13639288  0.149186    0.16273126  0.10240071
#   0.05315581 -0.12390375  0.04430173  0.19223318 -0.21017729  0.06085856
#   0.11135349  0.03212997 -0.0976584  -0.06608193  0.18084967  0.14651786
#  -0.10443388 -0.16257507  0.09258576 -0.17580147 -0.05392531  0.08754997
#  -0.09249908 -0.16342446 -0.2262428   0.06039719  0.40714678  0.15566698
# ...

# %%
for i, e in enumerate(x1['names']):
    if(i%50==0):
        print(x1['names'][i], x1['encodings'][i])
# Out:
# 001 [-0.0054642   0.12361583  0.0012942   0.00195411 -0.08104577  0.0632704
#  -0.05883571 -0.01335773  0.12938428 -0.0505349   0.10464559 -0.03721613
#  -0.23423989  0.08829327  0.02961041  0.06024803 -0.09637839 -0.13824268
#  -0.16970776 -0.12847993  0.01141689  0.11940365 -0.02860014  0.08176674
#  -0.20598143 -0.25302801 -0.0355272  -0.13440427  0.01257586 -0.08883356
#   0.02898649 -0.09090729 -0.15584025  0.03123279  0.0133211   0.03490157
#  -0.06243238 -0.11382256  0.26641005  0.014855   -0.18024229  0.0125556
#   0.04934499  0.27775276  0.11139196 -0.00203925  0.00429133  0.00910004
#   0.12024152 -0.23500541  0.15052211  0.1957887   0.13092646  0.15263014
#   0.05583726 -0.11755139  0.08053718  0.16549158 -0.20264952  0.08772322
#   0.08869329 -0.03938054 -0.00266977 -0.02052808  0.21744077  0.08202022
#  -0.08364694 -0.1194508   0.07205611 -0.21058026 -0.07311711  0.09206722
#  -0.0872105  -0.18109606 -0.25678217  0.0816321   0.391772    0.15729471
# ...
